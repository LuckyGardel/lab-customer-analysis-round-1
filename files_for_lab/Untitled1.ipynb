# %%
import pandas as pd
file1 = pd.read_csv('file1.csv')
display(file1.head(10))
display(file1.tail())
file1.shape
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
# 5  OC83172      Oregon      F              Bachelor              825629.78%
# 6  XZ87318      Oregon      F               College              538089.86%
# 7  CF85061     Arizona      M                Master              721610.03%
# 8  DY87989      Oregon      M              Bachelor             2412750.40%
# 9  BQ94931      Oregon      F               College              738817.81%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# ...

# %%
file2 = pd.read_csv('file2.csv')
display(file2.head(10))
display(file2.tail())
file2.shape
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
# 5  WL99637     Arizona      M  Bachelor              761413.80%   27293
# 6  UC84059  California      F    Master              689845.53%   70950
# 7  HW62747      Oregon      M   College              229837.92%       0
# 8  BH11344      Oregon      F    Doctor              280669.61%   37009
# 9  TX28465      Nevada      M   College              520611.82%   52629
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00          633.600000
# ...

# %%
file3 = pd.read_csv('file3.csv')
display(file3.head(10))
display(file3.tail())
file3.shape
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
# 5  VI78454     Arizona              2750.705045               College      M
# 6  FP59138      Oregon             13024.130120                Master      M
# 7  XN62489      Oregon              2538.626320              Bachelor      M
# 8  GP66031  California              2585.955652               College      F
# 9  IX68587      Nevada              5096.673223                Master      F
#
#    Income  Monthly Premium Auto  Number of Open Complaints     Policy Type  \
# ...

# %%
file1 = file1.rename(columns={'ST':'State',
                            'GENDER':'Gender'})
file1.head()
# Out:
#   Customer       State Gender             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
file2 = file2.rename(columns={'ST':'State',
                            'GENDER':'Gender'})
file2.head()
# Out:
#   Customer       State Gender Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       Policy Type  Vehicle Class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
file1=file1[['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
       'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
       'Policy Type', 'Total Claim Amount', 'Vehicle Class']]

# %%
print(file1.shape)
file1.head()
# Out:
# (4008, 11)
#   Customer       State Customer Lifetime Value             Education Gender  \
# 0  RB50392  Washington                     NaN                Master    NaN
# 1  QZ44356     Arizona              697953.59%              Bachelor      F
# 2  AI49188      Nevada             1288743.17%              Bachelor      F
# 3  WW63253  California              764586.18%              Bachelor      M
# 4  GA49547  Washington              536307.65%  High School or Below      M
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Total Claim Amount  Vehicle Class
# ...

# %%
file2=file2[['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
       'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
       'Policy Type', 'Total Claim Amount', 'Vehicle Class']]

# %%
print(file2.shape)
file2.head()
# Out:
# (996, 11)
#   Customer       State Customer Lifetime Value Education Gender  Income  \
# 0  GS98873     Arizona              323912.47%  Bachelor      F   16061
# 1  CW49887  California              462680.11%    Master      F   79487
# 2  MY31220  California              899704.02%   College      F   54230
# 3  UH35128      Oregon             2580706.30%   College      F   71210
# 4  WH52799     Arizona              380812.21%   College      F   94903
#
#    Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0                    88                    1/0/00   Personal Auto
# 1                   114                    1/0/00    Special Auto
# 2                   112                    1/0/00   Personal Auto
# 3                   214                    1/1/00   Personal Auto
# 4                    94                    1/0/00  Corporate Auto
#
#    Total Claim Amount  Vehicle Class
# 0               633.6  Four-Door Car
# 1               547.2            SUV
# ...

# %%
file3=file3[['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
       'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
       'Policy Type', 'Total Claim Amount', 'Vehicle Class']]

# %%
print(file3.shape)
file3.head()
# Out:
# (7070, 11)
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Total Claim Amount  Vehicle Class
# ...

# %%
column_names = file1.columns
column_names
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
column_names = file2.columns
column_names
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
column_names = file3.columns
column_names
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
file1['Customer Lifetime Value'] = file1['Customer Lifetime Value'].str.replace('%','')
file1['Customer Lifetime Value'] = pd.to_numeric(file1['Customer Lifetime Value'],errors = "coerce")

# %%
file1.head()
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  RB50392  Washington                      NaN                Master    NaN
# 1  QZ44356     Arizona                697953.59              Bachelor      F
# 2  AI49188      Nevada               1288743.17              Bachelor      F
# 3  WW63253  California                764586.18              Bachelor      M
# 4  GA49547  Washington                536307.65  High School or Below      M
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Total Claim Amount  Vehicle Class
# ...

# %%
file2['Customer Lifetime Value'] = file2['Customer Lifetime Value'].str.replace('%','')
file2['Customer Lifetime Value'] = pd.to_numeric(file2['Customer Lifetime Value'],errors = "coerce")

# %%
file2.head()
# Out:
#   Customer       State  Customer Lifetime Value Education Gender  Income  \
# 0  GS98873     Arizona                323912.47  Bachelor      F   16061
# 1  CW49887  California                462680.11    Master      F   79487
# 2  MY31220  California                899704.02   College      F   54230
# 3  UH35128      Oregon               2580706.30   College      F   71210
# 4  WH52799     Arizona                380812.21   College      F   94903
#
#    Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0                    88                    1/0/00   Personal Auto
# 1                   114                    1/0/00    Special Auto
# 2                   112                    1/0/00   Personal Auto
# 3                   214                    1/1/00   Personal Auto
# 4                    94                    1/0/00  Corporate Auto
#
#    Total Claim Amount  Vehicle Class
# 0               633.6  Four-Door Car
# 1               547.2            SUV
# ...

# %%
data = pd.concat([file1, file2, file3], axis=0) 
data.shape
data
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     RB50392  Washington                      NaN                Master
# 1     QZ44356     Arizona             6.979536e+05              Bachelor
# 2     AI49188      Nevada             1.288743e+06              Bachelor
# 3     WW63253  California             7.645862e+05              Bachelor
# 4     GA49547  Washington             5.363077e+05  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             2.340599e+04              Bachelor
# 7066  PK87824  California             3.096511e+03               College
# 7067  TD14365  California             8.163890e+03              Bachelor
# 7068  UP19263  California             7.524442e+03               College
# 7069  Y167826  California             2.611837e+03               College
#
#      Gender   Income  Monthly Premium Auto Number of Open Complaints  \
# ...

# %%
data.dtypes
# Out:
# Customer                      object
# State                         object
# Customer Lifetime Value      float64
# Education                     object
# Gender                        object
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                   object
# Total Claim Amount           float64
# Vehicle Class                 object
# dtype: object

# %%
for i in data ["Number of Open Complaints"].unique():
    print(i, type(i))
# Out:
# 1/0/00 <class 'str'>
# 1/2/00 <class 'str'>
# 1/1/00 <class 'str'>
# 1/3/00 <class 'str'>
# 1/5/00 <class 'str'>
# 1/4/00 <class 'str'>
# nan <class 'float'>
# 0 <class 'int'>
# 2 <class 'int'>
# 3 <class 'int'>
# 1 <class 'int'>
# 5 <class 'int'>
# 4 <class 'int'>

# %% [markdown]
# According to the formula the categorical columns are: Customer/ State / Education / Gender / Number of open Complaints/ Policy Type & Vehicle class.

# %% [markdown]
# According to the formula the numerical columns are: Customer Lifetime Value / Income / Monthly Premium Auto & Total Claim Amount.

# %% [markdown]
# For me Number of open complaints should be numerical too, thats why i got more deep into it to check the class of variable and it has both...

# %%
data = data.drop(['Education','Number of Open Complaints'], axis=1)
data.head()
# Out:
#   Customer       State  Customer Lifetime Value Gender   Income  \
# 0  RB50392  Washington                      NaN    NaN      0.0
# 1  QZ44356     Arizona                697953.59      F      0.0
# 2  AI49188      Nevada               1288743.17      F  48767.0
# 3  WW63253  California                764586.18      M      0.0
# 4  GA49547  Washington                536307.65      M  36357.0
#
#    Monthly Premium Auto     Policy Type  Total Claim Amount  Vehicle Class
# 0                1000.0   Personal Auto            2.704934  Four-Door Car
# 1                  94.0   Personal Auto         1131.464935  Four-Door Car
# 2                 108.0   Personal Auto          566.472247   Two-Door Car
# 3                 106.0  Corporate Auto          529.881344            SUV
# 4                  68.0   Personal Auto           17.269323  Four-Door Car

# %%
duplicate = data[data.duplicated()]
print(duplicate)
# Out:
#      Customer       State  Customer Lifetime Value Education Gender   Income  \
# 1072      NaN         NaN                      NaN       NaN    NaN      NaN
# 1073      NaN         NaN                      NaN       NaN    NaN      NaN
# 1074      NaN         NaN                      NaN       NaN    NaN      NaN
# 1075      NaN         NaN                      NaN       NaN    NaN      NaN
# 1076      NaN         NaN                      NaN       NaN    NaN      NaN
# ...       ...         ...                      ...       ...    ...      ...
# 4006      NaN         NaN                      NaN       NaN    NaN      NaN
# 4007      NaN         NaN                      NaN       NaN    NaN      NaN
# 0     GS98873     Arizona                323912.47  Bachelor      F  16061.0
# 1     CW49887  California                462680.11    Master      F  79487.0
# 2     MY31220  California                899704.02   College      F  54230.0
#
# ...

# %%
print(data.duplicated().sum())
# Out:
# 2939

# %%
data = data.drop_duplicates()

# %%
duplicate = data[data.duplicated()]
print(duplicate)
# Out:
# Empty DataFrame
# Columns: [Customer, State, Customer Lifetime Value, Education, Gender, Income, Monthly Premium Auto, Number of Open Complaints, Policy Type, Total Claim Amount, Vehicle Class]
# Index: []

# %%
print(data.duplicated().sum())
# Out:
# 0

# %%
data.shape
# Out:
# (6840, 11)

# %%
data = data[data['Income'] > 0]
print(data)
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 2     AI49188      Nevada             1.288743e+06              Bachelor
# 4     GA49547  Washington             5.363077e+05  High School or Below
# 5     OC83172      Oregon             8.256298e+05              Bachelor
# 6     XZ87318      Oregon             5.380899e+05               College
# 8     DY87989      Oregon             2.412750e+06              Bachelor
# ...       ...         ...                      ...                   ...
# 7063  TF56202  California             5.032165e+03               College
# 7064  YM19146  California             4.100399e+03               College
# 7065  LA72316  California             2.340599e+04              Bachelor
# 7066  PK87824  California             3.096511e+03               College
# 7068  UP19263  California             7.524442e+03               College
#
#      Gender   Income  Monthly Premium Auto Number of Open Complaints  \
# ...

# %%
data
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 2     AI49188      Nevada             1.288743e+06              Bachelor
# 4     GA49547  Washington             5.363077e+05  High School or Below
# 5     OC83172      Oregon             8.256298e+05              Bachelor
# 6     XZ87318      Oregon             5.380899e+05               College
# 8     DY87989      Oregon             2.412750e+06              Bachelor
# ...       ...         ...                      ...                   ...
# 7063  TF56202  California             5.032165e+03               College
# 7064  YM19146  California             4.100399e+03               College
# 7065  LA72316  California             2.340599e+04              Bachelor
# 7066  PK87824  California             3.096511e+03               College
# 7068  UP19263  California             7.524442e+03               College
#
#      Gender   Income  Monthly Premium Auto Number of Open Complaints  \
# ...
